# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import binscatter

# %%
data = pd.read_csv("/home/jcai/geometry_of_law/data_and_dictionary/citation_data.csv")

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'logcounts', 'predict_logcounts'], dtype='object')

# %%
fig, axes = plt.subplots(1, 1)
axes.binscatter(data['predict_logcounts'], data['logcounts'])
axes.legend()
